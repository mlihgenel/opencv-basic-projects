# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("input.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
def display(img, cmap=None):
    plt.figure(figsize=(8,10))
    plt.imshow(img, cmap=cmap)
    plt.axis("off")
    plt.show()

# %%
imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
display(imgGray, "gray")

# %%
_, thresh = cv2.threshold(imgGray, 190, 255, cv2.THRESH_BINARY)

# %%
display(thresh, "gray")

# %%
kernel = np.ones((3,3))
thresh = cv2.erode(thresh, kernel, iterations = 2)

# %%
display(thresh, "gray")

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_CCOMP, cv2.CHAIN_APPROX_SIMPLE)

# %%
hierarchy
# Out:
# array([[[ 1, -1, -1, -1],
#         [ 2,  0, -1, -1],
#         [ 3,  1, -1, -1],
#         [ 4,  2, -1, -1],
#         [ 5,  3, -1, -1],
#         [ 6,  4, -1, -1],
#         [ 7,  5, -1, -1],
#         [12,  6,  8, -1],
#         [ 9, -1, -1,  7],
#         [10,  8, -1,  7],
#         [11,  9, -1,  7],
#         [-1, 10, -1,  7],
#         [33,  7, 13, -1],
#         [14, -1, -1, 12],
#         [15, 13, -1, 12],
#         [16, 14, -1, 12],
#         [17, 15, -1, 12],
#         [18, 16, -1, 12],
#         [19, 17, -1, 12],
#         [20, 18, -1, 12],
#         [21, 19, -1, 12],
#         [22, 20, -1, 12],
#         [23, 21, -1, 12],
#         [24, 22, -1, 12],
#         [25, 23, -1, 12],
#         [26, 24, -1, 12],
#         [27, 25, -1, 12],
#         [28, 26, -1, 12],
#         [29, 27, -1, 12],
#         [30, 28, -1, 12],
#         [31, 29, -1, 12],
#         [32, 30, -1, 12],
#         [-1, 31, -1, 12],
#         [34, 12, -1, -1],
#         [35, 33, -1, -1],
# ...

# %%
cv2.moments(contours[10])
# Out:
# {'m00': 278.5,
#  'm10': 68945.83333333333,
#  'm01': 115379.33333333333,
#  'm20': 17076496.416666664,
#  'm11': 28557993.708333332,
#  'm02': 47810055.58333333,
#  'm30': 4231526189.9500003,
#  'm21': 7071887094.066667,
#  'm12': 11831392712.566666,
#  'm03': 19815214456.7,
#  'mu20': 8173.493766206596,
#  'mu11': -5468.719354678071,
#  'mu02': 9730.41118092495,
#  'mu30': -1036.4007192373795,
#  'mu21': -451.3470013671729,
#  'mu12': 2516.8063684623044,
#  'mu03': -1760.6961907028362,
#  'nu20': 0.10537979192463598,
#  'nu11': -0.07050748727219841,
#  'nu02': 0.12545292562973548,
#  'nu30': -0.0008006905575060162,
#  'nu21': -0.0003486964795038674,
#  'nu12': 0.0019444053413834159,
#  'nu03': -0.0013602584293553308}

# %%
cnt = contours[0]
M = cv2.moments(cnt)

# %%
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cx = int(M['m10']/M['m00'])
#       2 cy = int(M['m01']/M['m00'])
#
# ZeroDivisionError: float division by zero

# %%
count = 0
for i in range(len(contours)):

    if hierarchy[0][i][3] == 46:
        cnt = contours[i]
        M = cv2.moments(cnt)
        cx =i int(M['m10']/M['m00'])
        cy = int(M['m01']/M['m00'])
        count += 1
        cv2.drawContours(img, contours,i, (0,255,0), 3)
        cv2.putText(img, str(count),(cx, cy), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,0), 3)
# Out:
#   Cell In[16], line 7
#     cx =i int(M['m10']/M['m00'])
#           ^
# SyntaxError: invalid syntax

# %%
# hierarchy[0][i][3] == 46 bunlar dış konturlar

# %%
display(img)
